# %% [markdown]
# ### **Fine-tuning for Audio Classification with AST 🤗 Transformers**

# %%
model_checkpoint = "MIT/ast-finetuned-audioset-10-10-0.4593"
batch_size = 2

# %% [markdown]
# ### Loading the dataset

# %%
from datasets import load_dataset, load_metric
from transformers import AutoProcessor, ASTConfig, ASTModel, AutoFeatureExtractor, ASTForAudioClassification, TrainingArguments, Trainer

import torch
import torch.nn as nn
import yaml
import os
import torch
import torchaudio
import numpy as np
import datasets

from datasets import ClassLabel

# %%
with open("./confs/default.yaml", "r") as f:
        configs = yaml.safe_load(f)

# %%
data_files = {"train": configs["data"]["synth_tsv"], "test": configs["data"]["synth_val_tsv"]}
raw_dataset = load_dataset("csv", data_files=data_files, sep = "\t")
metric = load_metric("accuracy")
# Out:
# Found cached dataset csv (/home/unegi/.cache/huggingface/datasets/csv/default-03475b778f293dce/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/2 [00:00<?, ?it/s]
# /tmp/ipykernel_1242935/2144004976.py:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")

# %%
def process_data(example, audio_file_dir, num_samples, transformation, labels2id, target_sample_rate=16000):
    # This function will do what your __getitem__ method does
    
    # Load audio
    filepath = os.path.join(audio_file_dir, example['filename'])
    signal, sr = torchaudio.load(filepath)
    signal = signal.squeeze().numpy()
    #signal = signal.view(-1)
    label = example["event_label"]
    label_int = float(labels2id[label])
    example["label"] = label_int
    #example['label'] = torch.tensor(label_int)
    
    example["audio"] = {"array": np.array(signal), "path": filepath, "sampling_rate": sr}
    return example

# %%
from collections import OrderedDict


labels2id = OrderedDict(
    {
        "Alarm_bell_ringing": 0,
        "Blender": 1,
        "Cat": 2,
        "Dishes": 3,
        "Dog": 4,
        "Electric_shaver_toothbrush": 5,
        "Frying": 6,
        "Running_water": 7,
        "Speech": 8,
        "Vacuum_cleaner": 9,
    }
)

id2labels = {value: key for key, value in labels2id.items()}

# %%
SAMPLE_RATE = configs["data"]["fs"]
N_FFT = configs["feats"]["n_window"]
WIN_LENGTH = configs["feats"]["n_window"]
HOP_LENGTH = configs["feats"]["hop_length"]
F_MIN = configs["feats"]["f_min"]
F_MAX = configs["feats"]["f_max"]
N_MELS = configs["feats"]["n_mels"]
WINDOW_FN = torch.hamming_window
WKWARGS = {"periodic": False}
POWER = 1
NUM_SAMPLES = SAMPLE_RATE

# %%
partial_raw_train_dataset = raw_dataset["train"].select(range(10)).map(process_data, 
                                           fn_kwargs={'audio_file_dir': configs["data"]["synth_folder"], 
                                                      'num_samples': NUM_SAMPLES,
                                                       'transformation': None,
                                                        'labels2id': labels2id,
                                                        'target_sample_rate':16000, 
                                                        })
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
partial_raw_test_dataset = raw_dataset["test"].select(range(5)).map(process_data, 
                                           fn_kwargs={'audio_file_dir': configs["data"]["synth_folder"], 
                                                      'num_samples': NUM_SAMPLES,
                                                       'transformation': None,
                                                        'labels2id': labels2id,
                                                        'target_sample_rate':16000, 
                                                        })
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
raw_train_dataset = raw_dataset["train"].map(process_data, 
                                           fn_kwargs={'audio_file_dir': configs["data"]["synth_folder"], 
                                                      'num_samples': NUM_SAMPLES,
                                                       'transformation': None,
                                                        'labels2id': labels2id,
                                                        'target_sample_rate':16000, 
                                                        })
# Out:
# Loading cached processed dataset at /home/unegi/.cache/huggingface/datasets/csv/default-03475b778f293dce/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-324f9b638ea6090b.arrow

# %%
raw_test_dataset = raw_dataset["test"].map(process_data, 
                                           fn_kwargs={'audio_file_dir': configs["data"]["synth_folder"], 
                                                      'num_samples': NUM_SAMPLES,
                                                       'transformation': None,
                                                        'labels2id': labels2id,
                                                        'target_sample_rate':16000, 
                                                        })
# Out:
# Loading cached processed dataset at /home/unegi/.cache/huggingface/datasets/csv/default-03475b778f293dce/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-9dccc9695f7cf439.arrow

# %%
partial_raw_train_dataset.features
# Out:
# {'filename': Value(dtype='string', id=None),
#  'onset': Value(dtype='float64', id=None),
#  'offset': Value(dtype='float64', id=None),
#  'event_label': Value(dtype='string', id=None),
#  'label': Value(dtype='float64', id=None),
#  'audio': {'array': Sequence(feature=Value(dtype='float32', id=None), length=-1, id=None),
#   'path': Value(dtype='string', id=None),
#   'sampling_rate': Value(dtype='int64', id=None)}}

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained(model_checkpoint, device_map='cpu')

# %%
partial_raw_train_dataset_2 = partial_raw_train_dataset.remove_columns(["onset", "offset", "event_label"])

# %%
partial_raw_test_dataset_2 = partial_raw_test_dataset.remove_columns(["onset", "offset", "event_label"])

# %%
raw_train_dataset_2 = raw_train_dataset.remove_columns(["onset", "offset", "event_label"])

# %%
raw_test_dataset_2 = raw_test_dataset.remove_columns(["onset", "offset", "event_label"])

# %%
raw_train_dataset_2 = raw_train_dataset_2.cast_column("label", ClassLabel(names = list(labels2id.keys()) ))
# Out:
# Loading cached processed dataset at /home/unegi/.cache/huggingface/datasets/csv/default-03475b778f293dce/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-264ba74a4b672df3.arrow

# %%
raw_test_dataset_2 = raw_test_dataset_2.cast_column("label", ClassLabel(names = list(labels2id.keys()) ))
# Out:
# Loading cached processed dataset at /home/unegi/.cache/huggingface/datasets/csv/default-03475b778f293dce/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-79248f4d9aa294c1.arrow

# %%
partial_raw_train_dataset_2 = partial_raw_train_dataset_2.cast_column(
        "audio", datasets.features.Audio(sampling_rate=feature_extractor.sampling_rate)
    )
partial_raw_train_dataset_2 = partial_raw_train_dataset_2.cast_column("label", ClassLabel(names = list(labels2id.keys()) ))
# Out:
# Casting the dataset:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
partial_raw_test_dataset_2 = partial_raw_test_dataset_2.cast_column(
        "audio", datasets.features.Audio(sampling_rate=feature_extractor.sampling_rate)
    )
partial_raw_test_dataset_2 = partial_raw_test_dataset_2.cast_column("label", ClassLabel(names = list(labels2id.keys()) ))
# Out:
# Casting the dataset:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
partial_raw_test_dataset_2.features
# Out:
# {'filename': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['Alarm_bell_ringing', 'Blender', 'Cat', 'Dishes', 'Dog', 'Electric_shaver_toothbrush', 'Frying', 'Running_water', 'Speech', 'Vacuum_cleaner'], id=None),
#  'audio': Audio(sampling_rate=16000, mono=True, decode=True, id=None)}

# %%
partial_raw_train_dataset_2.features["label"]
# Out:
# ClassLabel(names=['Alarm_bell_ringing', 'Blender', 'Cat', 'Dishes', 'Dog', 'Electric_shaver_toothbrush', 'Frying', 'Running_water', 'Speech', 'Vacuum_cleaner'], id=None)

# %% [markdown]
# We can see that the audio file has automatically been loaded. This is thanks to the new [`"Audio"` feature](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=audio#datasets.Audio) introduced in `datasets == 1.13.3`, which loads and resamples audio files on-the-fly upon calling.
#
# The sampling rate is set to 16kHz which is what `Wav2Vec2` expects as an input.

# %%
import random
from IPython.display import Audio, display

for _ in range(1):
    rand_idx = random.randint(0, len(partial_raw_train_dataset_2)-1)
    example = partial_raw_train_dataset_2[rand_idx]
    audio = example["audio"]
    print(f'Label: {id2labels[(example["label"])]}')
    print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
    display(Audio(audio["array"], rate=audio["sampling_rate"]))
    print()
# Out:
# Label: Speech
# Shape: (160000,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Preprocessing the data

# %%
from transformers import AutoFeatureExtractor

feature_extractor = AutoFeatureExtractor.from_pretrained(model_checkpoint)
feature_extractor
# Out:
# ASTFeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "ASTFeatureExtractor",
#   "feature_size": 1,
#   "max_length": 1024,
#   "mean": -4.2677393,
#   "num_mel_bins": 128,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": false,
#   "sampling_rate": 16000,
#   "std": 4.5689974
# }

# %%
max_duration = 3.0  # seconds

# %%
def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
    )
    return inputs

# %%
preprocess_function(raw_train_dataset_2[:5])

# %%
#encoded_dataset_train = partial_raw_train_dataset_2.map(preprocess_function, remove_columns=["audio", "filename"], batched=True)
encoded_dataset_train = raw_train_dataset_2.map(preprocess_function, remove_columns=["audio", "filename"], batched=True)
encoded_dataset_train
# Out:
# Map:   0%|          | 0/32096 [00:00<?, ? examples/s]
# Dataset({
#     features: ['label', 'input_values'],
#     num_rows: 32096
# })

# %%
#encoded_dataset_test = partial_raw_test_dataset_2.map(preprocess_function, remove_columns=["audio", "filename"], batched=True)
encoded_dataset_test = raw_test_dataset_2.map(preprocess_function, remove_columns=["audio", "filename"], batched=True)
encoded_dataset_test
# Out:
# Map:   0%|          | 0/8132 [00:00<?, ? examples/s]
# Dataset({
#     features: ['label', 'input_values'],
#     num_rows: 8132
# })

# %% [markdown]
# ### Training the model

# %%
from transformers import AutoModelForAudioClassification, TrainingArguments, Trainer

num_labels = len(id2labels)
model = AutoModelForAudioClassification.from_pretrained(
    model_checkpoint,
    num_labels=num_labels,
    label2id=labels2id,
    id2label=id2labels,
    ignore_mismatched_sizes=True
)
# Out:
# Some weights of ASTForAudioClassification were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - classifier.dense.weight: found shape torch.Size([527, 768]) in the checkpoint and torch.Size([10, 768]) in the model instantiated
# - classifier.dense.bias: found shape torch.Size([527]) in the checkpoint and torch.Size([10]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Set the device to CPU
device = torch.device("cpu")

# %%
model_name = model_checkpoint.split("/")[-1]

args = TrainingArguments(
    f"{model_name}-finetuned-ks",
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=5,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
)

# %%
import numpy as np

def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %%
partial_raw_train_dataset_2
# Out:
# Dataset({
#     features: ['filename', 'label', 'audio'],
#     num_rows: 10
# })

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=encoded_dataset_train,
    eval_dataset=encoded_dataset_test,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)
# Out:
# [codecarbon INFO @ 20:15:31] [setup] RAM Tracking...
# [codecarbon INFO @ 20:15:31] [setup] GPU Tracking...
# [codecarbon INFO @ 20:15:31] No GPU found.
# [codecarbon INFO @ 20:15:31] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:15:31] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 20:15:33] CPU Model on constant consumption mode: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz
# [codecarbon INFO @ 20:15:33] >>> Tracker's metadata:
# [codecarbon INFO @ 20:15:33]   Platform system: Linux-5.19.0-43-generic-x86_64-with-glibc2.10
# [codecarbon INFO @ 20:15:33]   Python version: 3.8.5
# [codecarbon INFO @ 20:15:33]   CodeCarbon version: 2.2.4
# [codecarbon INFO @ 20:15:33]   Available RAM : 7.623 GB
# [codecarbon INFO @ 20:15:33]   CPU count: 8
# [codecarbon INFO @ 20:15:33]   CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz
# [codecarbon INFO @ 20:15:33]   GPU count: None
# [codecarbon INFO @ 20:15:33]   GPU model: None
# [codecarbon WARNING @ 20:15:36] Unable to access geographical location. Using 'Canada' as the default value - Exception : Expecting value: line 1 column 1 (char 0)

# %%
trainer.train()
# Out:
# /home/unegi/anaconda3/envs/dcase2023/lib/python3.8/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# [codecarbon INFO @ 20:15:52] Energy consumed for RAM : 0.000012 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:15:52] Energy consumed for all CPUs : 0.000135 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:15:52] 0.000147 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:16:07] Energy consumed for RAM : 0.000024 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:16:07] Energy consumed for all CPUs : 0.000271 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:16:07] 0.000295 kWh of electricity used since the beginning.
#     <div>
#
#       <progress value='394' max='20060' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  394/20060 4:18:13 < 215:54:33, 0.03 it/s, Epoch 0.10/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 20:16:22] Energy consumed for RAM : 0.000036 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:16:22] Energy consumed for all CPUs : 0.000406 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:16:22] 0.000442 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:16:37] Energy consumed for RAM : 0.000048 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:16:37] Energy consumed for all CPUs : 0.000542 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:16:37] 0.000589 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:16:52] Energy consumed for RAM : 0.000060 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:16:52] Energy consumed for all CPUs : 0.000677 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:16:52] 0.000737 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:17:07] Energy consumed for RAM : 0.000071 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:17:07] Energy consumed for all CPUs : 0.000812 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:17:07] 0.000884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:17:22] Energy consumed for RAM : 0.000083 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:17:22] Energy consumed for all CPUs : 0.000948 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:17:22] 0.001031 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:17:37] Energy consumed for RAM : 0.000095 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:17:37] Energy consumed for all CPUs : 0.001083 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:17:37] 0.001179 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:17:52] Energy consumed for RAM : 0.000107 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:17:52] Energy consumed for all CPUs : 0.001219 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:17:52] 0.001326 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:07] Energy consumed for RAM : 0.000119 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:18:07] Energy consumed for all CPUs : 0.001354 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:18:07] 0.001473 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:22] Energy consumed for RAM : 0.000131 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:18:22] Energy consumed for all CPUs : 0.001489 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:18:22] 0.001620 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:37] Energy consumed for RAM : 0.000143 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:18:37] Energy consumed for all CPUs : 0.001625 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:18:37] 0.001768 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:52] Energy consumed for RAM : 0.000155 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:18:52] Energy consumed for all CPUs : 0.001760 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:18:52] 0.001915 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:19:07] Energy consumed for RAM : 0.000167 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:19:07] Energy consumed for all CPUs : 0.001896 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:19:07] 0.002062 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:19:22] Energy consumed for RAM : 0.000179 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:19:22] Energy consumed for all CPUs : 0.002031 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:19:22] 0.002210 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:19:37] Energy consumed for RAM : 0.000191 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:19:37] Energy consumed for all CPUs : 0.002166 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:19:37] 0.002357 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:19:52] Energy consumed for RAM : 0.000202 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:19:52] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:19:52] 0.002504 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:20:07] Energy consumed for RAM : 0.000214 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:20:07] Energy consumed for all CPUs : 0.002437 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:20:07] 0.002652 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:20:22] Energy consumed for RAM : 0.000226 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:20:22] Energy consumed for all CPUs : 0.002573 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:20:22] 0.002799 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:20:37] Energy consumed for RAM : 0.000238 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:20:37] Energy consumed for all CPUs : 0.002708 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:20:37] 0.002946 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:20:52] Energy consumed for RAM : 0.000250 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:20:52] Energy consumed for all CPUs : 0.002843 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:20:52] 0.003094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:21:07] Energy consumed for RAM : 0.000262 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:21:07] Energy consumed for all CPUs : 0.002979 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:21:07] 0.003241 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:21:22] Energy consumed for RAM : 0.000274 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:21:22] Energy consumed for all CPUs : 0.003116 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:21:22] 0.003390 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:21:37] Energy consumed for RAM : 0.000286 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:21:37] Energy consumed for all CPUs : 0.003251 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:21:37] 0.003537 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:21:52] Energy consumed for RAM : 0.000298 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:21:52] Energy consumed for all CPUs : 0.003387 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:21:52] 0.003685 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:22:07] Energy consumed for RAM : 0.000310 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:22:07] Energy consumed for all CPUs : 0.003522 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:22:07] 0.003832 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:22:22] Energy consumed for RAM : 0.000322 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:22:22] Energy consumed for all CPUs : 0.003657 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:22:22] 0.003979 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:22:37] Energy consumed for RAM : 0.000334 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:22:37] Energy consumed for all CPUs : 0.003793 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:22:37] 0.004126 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:22:52] Energy consumed for RAM : 0.000345 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:22:52] Energy consumed for all CPUs : 0.003928 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:22:52] 0.004274 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:23:07] Energy consumed for RAM : 0.000357 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:23:07] Energy consumed for all CPUs : 0.004064 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:23:07] 0.004421 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:23:22] Energy consumed for RAM : 0.000369 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:23:22] Energy consumed for all CPUs : 0.004199 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:23:22] 0.004568 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:23:37] Energy consumed for RAM : 0.000381 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:23:37] Energy consumed for all CPUs : 0.004334 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:23:37] 0.004716 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:23:52] Energy consumed for RAM : 0.000393 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:23:52] Energy consumed for all CPUs : 0.004470 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:23:52] 0.004863 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:24:07] Energy consumed for RAM : 0.000405 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:24:07] Energy consumed for all CPUs : 0.004605 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:24:07] 0.005010 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:24:22] Energy consumed for RAM : 0.000417 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:24:22] Energy consumed for all CPUs : 0.004741 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:24:22] 0.005158 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:24:37] Energy consumed for RAM : 0.000429 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:24:37] Energy consumed for all CPUs : 0.004876 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:24:37] 0.005305 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:24:52] Energy consumed for RAM : 0.000441 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:24:52] Energy consumed for all CPUs : 0.005011 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:24:52] 0.005452 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:25:07] Energy consumed for RAM : 0.000453 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:25:07] Energy consumed for all CPUs : 0.005147 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:25:07] 0.005599 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:25:22] Energy consumed for RAM : 0.000465 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:25:22] Energy consumed for all CPUs : 0.005282 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:25:22] 0.005747 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:25:37] Energy consumed for RAM : 0.000476 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:25:37] Energy consumed for all CPUs : 0.005418 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:25:37] 0.005894 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:25:52] Energy consumed for RAM : 0.000488 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:25:52] Energy consumed for all CPUs : 0.005553 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:25:52] 0.006041 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:26:07] Energy consumed for RAM : 0.000500 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:26:07] Energy consumed for all CPUs : 0.005688 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:26:07] 0.006189 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:26:22] Energy consumed for RAM : 0.000512 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:26:22] Energy consumed for all CPUs : 0.005824 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:26:22] 0.006336 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:26:37] Energy consumed for RAM : 0.000524 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:26:37] Energy consumed for all CPUs : 0.005959 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:26:37] 0.006483 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:26:52] Energy consumed for RAM : 0.000536 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:26:52] Energy consumed for all CPUs : 0.006095 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:26:52] 0.006631 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:27:07] Energy consumed for RAM : 0.000548 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:27:07] Energy consumed for all CPUs : 0.006230 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:27:07] 0.006778 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:27:22] Energy consumed for RAM : 0.000560 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:27:22] Energy consumed for all CPUs : 0.006365 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:27:22] 0.006925 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:27:37] Energy consumed for RAM : 0.000572 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:27:37] Energy consumed for all CPUs : 0.006501 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:27:37] 0.007073 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:27:52] Energy consumed for RAM : 0.000584 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:27:52] Energy consumed for all CPUs : 0.006636 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:27:52] 0.007220 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:28:07] Energy consumed for RAM : 0.000596 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:28:07] Energy consumed for all CPUs : 0.006772 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:28:07] 0.007367 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:28:22] Energy consumed for RAM : 0.000607 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:28:22] Energy consumed for all CPUs : 0.006907 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:28:22] 0.007514 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:28:37] Energy consumed for RAM : 0.000619 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:28:37] Energy consumed for all CPUs : 0.007042 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:28:37] 0.007662 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:28:52] Energy consumed for RAM : 0.000631 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:28:52] Energy consumed for all CPUs : 0.007178 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:28:52] 0.007809 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:29:07] Energy consumed for RAM : 0.000643 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:29:07] Energy consumed for all CPUs : 0.007313 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:29:07] 0.007956 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:29:22] Energy consumed for RAM : 0.000655 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:29:22] Energy consumed for all CPUs : 0.007449 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:29:22] 0.008104 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:29:37] Energy consumed for RAM : 0.000667 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:29:37] Energy consumed for all CPUs : 0.007584 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:29:37] 0.008251 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:29:52] Energy consumed for RAM : 0.000679 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:29:52] Energy consumed for all CPUs : 0.007719 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:29:52] 0.008398 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:30:07] Energy consumed for RAM : 0.000691 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:30:07] Energy consumed for all CPUs : 0.007855 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:30:07] 0.008546 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:30:22] Energy consumed for RAM : 0.000703 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:30:22] Energy consumed for all CPUs : 0.007990 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:30:22] 0.008693 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:30:37] Energy consumed for RAM : 0.000715 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:30:37] Energy consumed for all CPUs : 0.008126 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:30:37] 0.008840 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:30:52] Energy consumed for RAM : 0.000727 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:30:52] Energy consumed for all CPUs : 0.008261 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:30:52] 0.008988 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:31:07] Energy consumed for RAM : 0.000738 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:31:07] Energy consumed for all CPUs : 0.008396 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:31:07] 0.009135 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:31:22] Energy consumed for RAM : 0.000750 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:31:22] Energy consumed for all CPUs : 0.008532 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:31:22] 0.009282 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:31:37] Energy consumed for RAM : 0.000762 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:31:37] Energy consumed for all CPUs : 0.008667 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:31:37] 0.009429 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:31:52] Energy consumed for RAM : 0.000774 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:31:52] Energy consumed for all CPUs : 0.008803 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:31:52] 0.009577 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:32:07] Energy consumed for RAM : 0.000786 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:32:07] Energy consumed for all CPUs : 0.008938 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:32:07] 0.009724 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:32:22] Energy consumed for RAM : 0.000798 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:32:22] Energy consumed for all CPUs : 0.009073 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:32:22] 0.009871 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:32:37] Energy consumed for RAM : 0.000810 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:32:37] Energy consumed for all CPUs : 0.009210 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:32:37] 0.010020 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:32:52] Energy consumed for RAM : 0.000822 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:32:52] Energy consumed for all CPUs : 0.009345 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:32:52] 0.010167 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:33:07] Energy consumed for RAM : 0.000834 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:33:07] Energy consumed for all CPUs : 0.009481 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:33:07] 0.010315 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:33:22] Energy consumed for RAM : 0.000846 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:33:22] Energy consumed for all CPUs : 0.009616 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:33:22] 0.010462 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:33:37] Energy consumed for RAM : 0.000858 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:33:37] Energy consumed for all CPUs : 0.009752 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:33:37] 0.010609 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:33:52] Energy consumed for RAM : 0.000870 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:33:52] Energy consumed for all CPUs : 0.009887 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:33:52] 0.010757 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:34:07] Energy consumed for RAM : 0.000881 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:34:07] Energy consumed for all CPUs : 0.010022 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:34:07] 0.010904 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:34:22] Energy consumed for RAM : 0.000893 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:34:22] Energy consumed for all CPUs : 0.010158 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:34:22] 0.011051 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:34:37] Energy consumed for RAM : 0.000905 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:34:37] Energy consumed for all CPUs : 0.010293 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:34:37] 0.011198 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:34:52] Energy consumed for RAM : 0.000917 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:34:52] Energy consumed for all CPUs : 0.010429 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:34:52] 0.011346 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:35:07] Energy consumed for RAM : 0.000929 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:35:07] Energy consumed for all CPUs : 0.010564 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:35:07] 0.011493 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:35:22] Energy consumed for RAM : 0.000941 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:35:22] Energy consumed for all CPUs : 0.010699 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:35:22] 0.011640 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:35:37] Energy consumed for RAM : 0.000953 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:35:37] Energy consumed for all CPUs : 0.010835 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:35:37] 0.011788 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:35:52] Energy consumed for RAM : 0.000965 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:35:52] Energy consumed for all CPUs : 0.010970 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:35:52] 0.011935 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:36:07] Energy consumed for RAM : 0.000977 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:36:07] Energy consumed for all CPUs : 0.011106 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:36:07] 0.012082 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:36:22] Energy consumed for RAM : 0.000989 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:36:22] Energy consumed for all CPUs : 0.011241 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:36:22] 0.012230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:36:37] Energy consumed for RAM : 0.001001 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:36:37] Energy consumed for all CPUs : 0.011376 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:36:37] 0.012377 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:36:52] Energy consumed for RAM : 0.001012 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:36:52] Energy consumed for all CPUs : 0.011512 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:36:52] 0.012524 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:37:07] Energy consumed for RAM : 0.001024 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:37:07] Energy consumed for all CPUs : 0.011647 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:37:07] 0.012672 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:37:22] Energy consumed for RAM : 0.001036 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:37:22] Energy consumed for all CPUs : 0.011783 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:37:22] 0.012819 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:37:37] Energy consumed for RAM : 0.001048 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:37:37] Energy consumed for all CPUs : 0.011918 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:37:37] 0.012966 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:37:52] Energy consumed for RAM : 0.001060 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:37:52] Energy consumed for all CPUs : 0.012053 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:37:52] 0.013113 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:38:07] Energy consumed for RAM : 0.001072 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:38:07] Energy consumed for all CPUs : 0.012189 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:38:07] 0.013261 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:38:22] Energy consumed for RAM : 0.001084 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:38:22] Energy consumed for all CPUs : 0.012324 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:38:22] 0.013408 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:38:37] Energy consumed for RAM : 0.001096 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:38:37] Energy consumed for all CPUs : 0.012460 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:38:37] 0.013555 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:38:52] Energy consumed for RAM : 0.001108 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:38:52] Energy consumed for all CPUs : 0.012595 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:38:52] 0.013703 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:39:07] Energy consumed for RAM : 0.001120 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:39:07] Energy consumed for all CPUs : 0.012730 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:39:07] 0.013850 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:39:22] Energy consumed for RAM : 0.001132 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:39:22] Energy consumed for all CPUs : 0.012866 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:39:22] 0.013997 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:39:37] Energy consumed for RAM : 0.001143 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:39:37] Energy consumed for all CPUs : 0.013001 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:39:37] 0.014145 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:39:52] Energy consumed for RAM : 0.001155 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:39:52] Energy consumed for all CPUs : 0.013137 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:39:52] 0.014292 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:40:07] Energy consumed for RAM : 0.001167 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:40:07] Energy consumed for all CPUs : 0.013272 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:40:07] 0.014439 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:40:22] Energy consumed for RAM : 0.001179 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:40:22] Energy consumed for all CPUs : 0.013407 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:40:22] 0.014587 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:40:37] Energy consumed for RAM : 0.001191 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:40:37] Energy consumed for all CPUs : 0.013543 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:40:37] 0.014734 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:40:52] Energy consumed for RAM : 0.001203 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:40:52] Energy consumed for all CPUs : 0.013678 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:40:52] 0.014881 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:41:07] Energy consumed for RAM : 0.001215 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:41:07] Energy consumed for all CPUs : 0.013814 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:41:07] 0.015028 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:41:22] Energy consumed for RAM : 0.001227 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:41:22] Energy consumed for all CPUs : 0.013949 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:41:22] 0.015176 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:41:37] Energy consumed for RAM : 0.001239 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:41:37] Energy consumed for all CPUs : 0.014084 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:41:37] 0.015323 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:41:52] Energy consumed for RAM : 0.001251 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:41:52] Energy consumed for all CPUs : 0.014220 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:41:52] 0.015470 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:42:07] Energy consumed for RAM : 0.001262 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:42:07] Energy consumed for all CPUs : 0.014355 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:42:07] 0.015618 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:42:22] Energy consumed for RAM : 0.001274 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:42:22] Energy consumed for all CPUs : 0.014491 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:42:22] 0.015765 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:42:37] Energy consumed for RAM : 0.001286 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:42:37] Energy consumed for all CPUs : 0.014626 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:42:37] 0.015912 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:42:52] Energy consumed for RAM : 0.001298 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:42:52] Energy consumed for all CPUs : 0.014761 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:42:52] 0.016060 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:43:07] Energy consumed for RAM : 0.001310 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:43:07] Energy consumed for all CPUs : 0.014897 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:43:07] 0.016207 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:43:22] Energy consumed for RAM : 0.001322 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:43:22] Energy consumed for all CPUs : 0.015032 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:43:22] 0.016354 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:43:37] Energy consumed for RAM : 0.001334 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:43:37] Energy consumed for all CPUs : 0.015168 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:43:37] 0.016502 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:43:52] Energy consumed for RAM : 0.001346 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:43:52] Energy consumed for all CPUs : 0.015303 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:43:52] 0.016649 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:44:07] Energy consumed for RAM : 0.001358 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:44:07] Energy consumed for all CPUs : 0.015438 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:44:07] 0.016796 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:44:22] Energy consumed for RAM : 0.001370 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:44:22] Energy consumed for all CPUs : 0.015575 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:44:22] 0.016945 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:44:37] Energy consumed for RAM : 0.001382 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:44:37] Energy consumed for all CPUs : 0.015711 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:44:37] 0.017092 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:44:52] Energy consumed for RAM : 0.001394 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:44:52] Energy consumed for all CPUs : 0.015846 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:44:52] 0.017240 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:45:07] Energy consumed for RAM : 0.001406 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:45:07] Energy consumed for all CPUs : 0.015981 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:45:07] 0.017387 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:45:22] Energy consumed for RAM : 0.001417 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:45:22] Energy consumed for all CPUs : 0.016117 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:45:22] 0.017534 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:45:37] Energy consumed for RAM : 0.001429 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:45:37] Energy consumed for all CPUs : 0.016252 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:45:37] 0.017682 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:45:52] Energy consumed for RAM : 0.001441 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:45:52] Energy consumed for all CPUs : 0.016388 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:45:52] 0.017829 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:46:07] Energy consumed for RAM : 0.001453 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:46:07] Energy consumed for all CPUs : 0.016523 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:46:07] 0.017976 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:46:22] Energy consumed for RAM : 0.001465 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:46:22] Energy consumed for all CPUs : 0.016658 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:46:22] 0.018123 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:46:37] Energy consumed for RAM : 0.001477 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:46:37] Energy consumed for all CPUs : 0.016794 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:46:37] 0.018271 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:46:52] Energy consumed for RAM : 0.001489 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:46:52] Energy consumed for all CPUs : 0.016929 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:46:52] 0.018418 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:47:07] Energy consumed for RAM : 0.001501 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:47:07] Energy consumed for all CPUs : 0.017065 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:47:07] 0.018565 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:47:22] Energy consumed for RAM : 0.001513 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:47:22] Energy consumed for all CPUs : 0.017200 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:47:22] 0.018713 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:47:37] Energy consumed for RAM : 0.001525 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:47:37] Energy consumed for all CPUs : 0.017335 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:47:37] 0.018860 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:47:52] Energy consumed for RAM : 0.001536 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:47:52] Energy consumed for all CPUs : 0.017471 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:47:52] 0.019007 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:48:07] Energy consumed for RAM : 0.001548 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:48:07] Energy consumed for all CPUs : 0.017606 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:48:07] 0.019155 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:48:22] Energy consumed for RAM : 0.001560 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:48:22] Energy consumed for all CPUs : 0.017742 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:48:22] 0.019302 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:48:37] Energy consumed for RAM : 0.001572 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:48:37] Energy consumed for all CPUs : 0.017877 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:48:37] 0.019449 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:48:52] Energy consumed for RAM : 0.001584 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:48:52] Energy consumed for all CPUs : 0.018012 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:48:52] 0.019596 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:49:07] Energy consumed for RAM : 0.001596 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:49:07] Energy consumed for all CPUs : 0.018148 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:49:07] 0.019744 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:49:22] Energy consumed for RAM : 0.001608 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:49:22] Energy consumed for all CPUs : 0.018283 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:49:22] 0.019891 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:49:37] Energy consumed for RAM : 0.001620 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:49:37] Energy consumed for all CPUs : 0.018419 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:49:37] 0.020038 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:49:52] Energy consumed for RAM : 0.001632 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:49:52] Energy consumed for all CPUs : 0.018554 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:49:52] 0.020186 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:50:07] Energy consumed for RAM : 0.001644 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:50:07] Energy consumed for all CPUs : 0.018689 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:50:07] 0.020333 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:50:22] Energy consumed for RAM : 0.001656 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:50:22] Energy consumed for all CPUs : 0.018825 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:50:22] 0.020480 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:50:37] Energy consumed for RAM : 0.001667 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:50:37] Energy consumed for all CPUs : 0.018960 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:50:37] 0.020628 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:50:52] Energy consumed for RAM : 0.001679 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:50:52] Energy consumed for all CPUs : 0.019096 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:50:52] 0.020775 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:51:07] Energy consumed for RAM : 0.001691 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:51:07] Energy consumed for all CPUs : 0.019231 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:51:07] 0.020922 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:51:22] Energy consumed for RAM : 0.001703 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:51:22] Energy consumed for all CPUs : 0.019366 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:51:22] 0.021070 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:51:37] Energy consumed for RAM : 0.001715 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:51:37] Energy consumed for all CPUs : 0.019502 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:51:37] 0.021217 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:51:52] Energy consumed for RAM : 0.001727 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:51:52] Energy consumed for all CPUs : 0.019637 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:51:52] 0.021364 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:52:07] Energy consumed for RAM : 0.001739 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:52:07] Energy consumed for all CPUs : 0.019773 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:52:07] 0.021512 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:52:22] Energy consumed for RAM : 0.001751 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:52:22] Energy consumed for all CPUs : 0.019908 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:52:22] 0.021659 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:52:37] Energy consumed for RAM : 0.001763 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:52:37] Energy consumed for all CPUs : 0.020043 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:52:37] 0.021806 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:52:52] Energy consumed for RAM : 0.001775 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:52:52] Energy consumed for all CPUs : 0.020179 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:52:52] 0.021953 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:53:07] Energy consumed for RAM : 0.001787 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:53:07] Energy consumed for all CPUs : 0.020314 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:53:07] 0.022101 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:53:22] Energy consumed for RAM : 0.001798 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:53:22] Energy consumed for all CPUs : 0.020450 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:53:22] 0.022248 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:53:37] Energy consumed for RAM : 0.001810 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:53:37] Energy consumed for all CPUs : 0.020585 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:53:37] 0.022395 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:53:52] Energy consumed for RAM : 0.001822 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:53:52] Energy consumed for all CPUs : 0.020720 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:53:52] 0.022543 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:54:07] Energy consumed for RAM : 0.001834 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:54:07] Energy consumed for all CPUs : 0.020856 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:54:07] 0.022690 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:54:22] Energy consumed for RAM : 0.001846 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:54:22] Energy consumed for all CPUs : 0.020991 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:54:22] 0.022837 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:54:37] Energy consumed for RAM : 0.001858 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:54:37] Energy consumed for all CPUs : 0.021127 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:54:37] 0.022985 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:54:52] Energy consumed for RAM : 0.001870 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:54:52] Energy consumed for all CPUs : 0.021262 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:54:52] 0.023132 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:55:07] Energy consumed for RAM : 0.001882 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:55:07] Energy consumed for all CPUs : 0.021397 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:55:07] 0.023279 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:55:22] Energy consumed for RAM : 0.001894 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:55:22] Energy consumed for all CPUs : 0.021533 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:55:22] 0.023427 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:55:37] Energy consumed for RAM : 0.001906 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:55:37] Energy consumed for all CPUs : 0.021668 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:55:37] 0.023574 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:55:52] Energy consumed for RAM : 0.001918 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:55:52] Energy consumed for all CPUs : 0.021804 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:55:52] 0.023721 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:56:07] Energy consumed for RAM : 0.001929 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:56:07] Energy consumed for all CPUs : 0.021939 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:56:07] 0.023869 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:56:22] Energy consumed for RAM : 0.001941 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:56:22] Energy consumed for all CPUs : 0.022074 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:56:22] 0.024016 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:56:37] Energy consumed for RAM : 0.001953 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:56:37] Energy consumed for all CPUs : 0.022210 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:56:37] 0.024163 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:56:52] Energy consumed for RAM : 0.001965 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:56:52] Energy consumed for all CPUs : 0.022345 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:56:52] 0.024310 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:57:07] Energy consumed for RAM : 0.001977 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:57:07] Energy consumed for all CPUs : 0.022481 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 20:57:07] 0.024458 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:57:22] Energy consumed for RAM : 0.001989 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 20:57:22] Energy consumed for all CPUs : 0.022616 kWh. Total CPU Power : 32.5 W
# ...
# [codecarbon INFO @ 00:20:42] 0.144410 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:20:57] Energy consumed for RAM : 0.011686 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:20:57] Energy consumed for all CPUs : 0.132872 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:20:57] 0.144558 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:21:12] Energy consumed for RAM : 0.011697 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:21:12] Energy consumed for all CPUs : 0.133008 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:21:12] 0.144705 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:21:27] Energy consumed for RAM : 0.011709 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:21:27] Energy consumed for all CPUs : 0.133143 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:21:27] 0.144852 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:21:42] Energy consumed for RAM : 0.011721 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:21:42] Energy consumed for all CPUs : 0.133278 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:21:42] 0.145000 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:21:57] Energy consumed for RAM : 0.011733 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:21:57] Energy consumed for all CPUs : 0.133414 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:21:57] 0.145147 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:22:12] Energy consumed for RAM : 0.011745 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:22:12] Energy consumed for all CPUs : 0.133549 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:22:12] 0.145294 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:22:27] Energy consumed for RAM : 0.011757 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:22:27] Energy consumed for all CPUs : 0.133685 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:22:27] 0.145442 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:22:42] Energy consumed for RAM : 0.011769 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:22:42] Energy consumed for all CPUs : 0.133820 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:22:42] 0.145589 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:22:57] Energy consumed for RAM : 0.011781 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:22:57] Energy consumed for all CPUs : 0.133955 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:22:57] 0.145736 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:23:12] Energy consumed for RAM : 0.011793 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:23:12] Energy consumed for all CPUs : 0.134091 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:23:12] 0.145884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:23:27] Energy consumed for RAM : 0.011805 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:23:27] Energy consumed for all CPUs : 0.134226 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:23:27] 0.146031 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:23:42] Energy consumed for RAM : 0.011817 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:23:42] Energy consumed for all CPUs : 0.134362 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:23:42] 0.146178 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:23:57] Energy consumed for RAM : 0.011828 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:23:57] Energy consumed for all CPUs : 0.134497 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:23:57] 0.146326 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:24:12] Energy consumed for RAM : 0.011840 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:24:12] Energy consumed for all CPUs : 0.134632 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:24:12] 0.146473 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:24:27] Energy consumed for RAM : 0.011852 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:24:27] Energy consumed for all CPUs : 0.134768 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:24:27] 0.146620 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:24:42] Energy consumed for RAM : 0.011864 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:24:42] Energy consumed for all CPUs : 0.134903 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:24:42] 0.146767 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:24:57] Energy consumed for RAM : 0.011876 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:24:57] Energy consumed for all CPUs : 0.135039 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:24:57] 0.146915 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:25:12] Energy consumed for RAM : 0.011888 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:25:12] Energy consumed for all CPUs : 0.135174 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:25:12] 0.147062 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:25:27] Energy consumed for RAM : 0.011900 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:25:27] Energy consumed for all CPUs : 0.135309 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:25:27] 0.147209 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:25:42] Energy consumed for RAM : 0.011912 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:25:42] Energy consumed for all CPUs : 0.135445 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:25:42] 0.147357 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:25:57] Energy consumed for RAM : 0.011924 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:25:57] Energy consumed for all CPUs : 0.135580 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:25:57] 0.147504 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:26:12] Energy consumed for RAM : 0.011936 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:26:12] Energy consumed for all CPUs : 0.135716 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:26:12] 0.147651 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:26:27] Energy consumed for RAM : 0.011948 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:26:27] Energy consumed for all CPUs : 0.135851 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:26:27] 0.147799 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:26:42] Energy consumed for RAM : 0.011959 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:26:42] Energy consumed for all CPUs : 0.135986 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:26:42] 0.147946 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:26:57] Energy consumed for RAM : 0.011971 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:26:57] Energy consumed for all CPUs : 0.136122 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:26:57] 0.148093 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:27:12] Energy consumed for RAM : 0.011983 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:27:12] Energy consumed for all CPUs : 0.136257 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:27:12] 0.148241 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:27:27] Energy consumed for RAM : 0.011995 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:27:27] Energy consumed for all CPUs : 0.136393 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:27:27] 0.148388 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:27:42] Energy consumed for RAM : 0.012007 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:27:42] Energy consumed for all CPUs : 0.136528 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:27:42] 0.148535 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:27:57] Energy consumed for RAM : 0.012019 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:27:57] Energy consumed for all CPUs : 0.136663 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:27:57] 0.148682 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:28:12] Energy consumed for RAM : 0.012031 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:28:12] Energy consumed for all CPUs : 0.136799 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:28:12] 0.148830 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:28:27] Energy consumed for RAM : 0.012043 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:28:27] Energy consumed for all CPUs : 0.136934 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:28:27] 0.148977 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:28:42] Energy consumed for RAM : 0.012055 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:28:42] Energy consumed for all CPUs : 0.137070 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:28:42] 0.149124 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:28:57] Energy consumed for RAM : 0.012067 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:28:57] Energy consumed for all CPUs : 0.137205 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:28:57] 0.149272 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:29:12] Energy consumed for RAM : 0.012079 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:29:12] Energy consumed for all CPUs : 0.137340 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:29:12] 0.149419 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:29:27] Energy consumed for RAM : 0.012090 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:29:27] Energy consumed for all CPUs : 0.137476 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:29:27] 0.149566 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:29:42] Energy consumed for RAM : 0.012102 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:29:42] Energy consumed for all CPUs : 0.137611 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:29:42] 0.149714 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:29:57] Energy consumed for RAM : 0.012114 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:29:57] Energy consumed for all CPUs : 0.137747 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:29:57] 0.149861 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:30:12] Energy consumed for RAM : 0.012126 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:30:12] Energy consumed for all CPUs : 0.137882 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:30:12] 0.150008 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:30:27] Energy consumed for RAM : 0.012138 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:30:27] Energy consumed for all CPUs : 0.138017 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:30:27] 0.150156 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:30:42] Energy consumed for RAM : 0.012150 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:30:42] Energy consumed for all CPUs : 0.138153 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:30:42] 0.150303 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:30:57] Energy consumed for RAM : 0.012162 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:30:57] Energy consumed for all CPUs : 0.138288 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:30:57] 0.150450 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:31:12] Energy consumed for RAM : 0.012174 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:31:12] Energy consumed for all CPUs : 0.138424 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:31:12] 0.150597 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:31:27] Energy consumed for RAM : 0.012186 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:31:27] Energy consumed for all CPUs : 0.138559 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:31:27] 0.150745 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:31:42] Energy consumed for RAM : 0.012198 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:31:42] Energy consumed for all CPUs : 0.138694 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:31:42] 0.150892 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:31:57] Energy consumed for RAM : 0.012210 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:31:57] Energy consumed for all CPUs : 0.138830 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:31:57] 0.151039 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:32:12] Energy consumed for RAM : 0.012221 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:32:12] Energy consumed for all CPUs : 0.138965 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:32:12] 0.151187 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:32:27] Energy consumed for RAM : 0.012233 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:32:27] Energy consumed for all CPUs : 0.139101 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:32:27] 0.151334 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:32:42] Energy consumed for RAM : 0.012245 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:32:42] Energy consumed for all CPUs : 0.139236 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:32:42] 0.151481 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:32:57] Energy consumed for RAM : 0.012257 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:32:57] Energy consumed for all CPUs : 0.139371 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:32:57] 0.151629 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:33:12] Energy consumed for RAM : 0.012269 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:33:12] Energy consumed for all CPUs : 0.139508 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:33:12] 0.151777 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:33:27] Energy consumed for RAM : 0.012281 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:33:27] Energy consumed for all CPUs : 0.139643 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:33:27] 0.151925 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:33:42] Energy consumed for RAM : 0.012293 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:33:42] Energy consumed for all CPUs : 0.139779 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:33:42] 0.152072 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:33:57] Energy consumed for RAM : 0.012305 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:33:57] Energy consumed for all CPUs : 0.139914 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:33:57] 0.152219 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:34:12] Energy consumed for RAM : 0.012317 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:34:12] Energy consumed for all CPUs : 0.140050 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:34:12] 0.152367 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:34:27] Energy consumed for RAM : 0.012329 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:34:27] Energy consumed for all CPUs : 0.140185 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:34:27] 0.152514 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:34:42] Energy consumed for RAM : 0.012341 kWh. RAM Power : 2.858745574951172 W
# [codecarbon INFO @ 00:34:42] Energy consumed for all CPUs : 0.140321 kWh. Total CPU Power : 32.5 W
# [codecarbon INFO @ 00:34:42] 0.152661 kWh of electricity used since the beginning.

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:07]
#     </div>
# {'eval_loss': 1.7789722681045532,
#  'eval_accuracy': 0.4,
#  'eval_runtime': 11.8693,
#  'eval_samples_per_second': 0.421,
#  'eval_steps_per_second': 0.253,
#  'epoch': 4.0}

# %% [markdown]
# #### Prediction

# %%
idx = random.randint(0, len(partial_raw_train_dataset_2)-1)
os.listdir(configs["data"]["synth_folder"])[idx]
# Out:
# '183.wav'

# %%
test_file = os.path.join(configs["data"]["synth_folder"], os.listdir(configs["data"]["synth_folder"])[idx])
test_file
# Out:
# '../../data/dcase/dataset/dcase_synth/audio/train/synthetic21_train/soundscapes_16k/183.wav'

# %%
waveform, sampling_rate = torchaudio.load(test_file)
waveform = waveform.squeeze().numpy()

# %%
inputs = feature_extractor(waveform, sampling_rate=sampling_rate, padding="max_length", return_tensors="pt")
input_values = inputs.input_values

# %%
with torch.no_grad():
  outputs = model(input_values)

# %%
from IPython.display import Audio

Audio(test_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predicted_class_idx = outputs.logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: Frying
